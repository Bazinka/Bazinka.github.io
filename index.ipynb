# %% [markdown]
# ### Dataset construction
# 1. [First step](./make_school_data/main/score_first_step.html)
# 2. [Second step](./make_school_data/main/score_second_step.html)
# 3. [Third step](./make_school_data/main/score_third_step.html)
#
#
# [Column description](./make_school_data/main/column_description.html)
#
# ### Classifications
# 1. [Denomination classificator](./schools_analytics/Denomination_classificator.html)
# 2. [CET score level classificator](./schools_analytics/CET_score_classificator.html)
